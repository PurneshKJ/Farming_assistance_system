# %%
# %cd yolov5

import torch
import os
from IPython.display import Image, clear_output  # to display images
# Out:
# C:\Users\kjpoo\Documents\UniversityOfGlasgow\Courses\MscProject\implementation\src\yolov5

# %%
# !python train.py --img 512 --batch 32 --epochs 20 --data ../Weed.yaml --weights yolov5s.pt --cache
# Out:
# github:  YOLOv5 is out of date by 17 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# train: weights=yolov5s.pt, cfg=, data=../Weed.yaml, hyp=data\hyps\hyp.scratch.yaml, epochs=20, batch_size=32, imgsz=512, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=1, project=runs\train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# From https://github.com/ultralytics/yolov5
#    7a39803..92a7391  master                  -> origin/master
#    cdd161a..9451512  classifier              -> origin/classifier
#    e6e3510..9e475ad  python_version_CI_tests -> origin/python_version_CI_tests
# ...

# %%
# !python detect.py --weights runs/train/exp8/weights/best.pt --img 512 --conf 0.25 --source ../../data/weeds/agri_data/data/Test
# Out:
# detect: weights=['runs/train/exp8/weights/best.pt'], source=../../data/weeds/agri_data/data/Test, imgsz=[512, 512], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.0-103-g7a39803 torch 1.10.0 CUDA:0 (GeForce RTX 2060, 6144MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/100 C:\Users\kjpoo\Documents\UniversityOfGlasgow\Courses\MscProject\implementation\data\weeds\agri_data\data\Test\agri_0_106.jpeg: 512x512 1 weed, Done. (0.011s)
# image 2/100 C:\Users\kjpoo\Documents\UniversityOfGlasgow\Courses\MscProject\implementation\data\weeds\agri_data\data\Test\agri_0_110.jpeg: 512x512 6 crops, Done. (0.012s)
# ...

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

for imageName in glob.glob('runs/detect/exp4/*.jpeg'): #assuming JPG
    
    display(Image(filename=imageName))
    print("\n")

# %%
# !python val.py --task test --weights runs/train/exp8/weights/best.pt --img 512 --conf-thres 0.25 --data ../Weed.yaml --device "cpu"
# Out:
# val: data=../Weed.yaml, weights=['runs/train/exp8/weights/best.pt'], batch_size=32, imgsz=512, conf_thres=0.25, iou_thres=0.6, task=test, device=cpu, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs\val, name=exp, exist_ok=False, half=False, dnn=False
# WARNING: confidence threshold 0.25 >> 0.001 will produce invalid mAP values.
# YOLOv5  v6.0-103-g7a39803 torch 1.10.0 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#
# test: Scanning '..\..\data\weeds\agri_data\data\Test' images and labels...:   0%|          | 0/100 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "C:\Users\kjpoo\anaconda3\envs\tensorflow_gpu\lib\multiprocessing\spawn.py", line 105, in spawn_main
#     exitcode = _main(fd)
#   File "C:\Users\kjpoo\anaconda3\envs\tensorflow_gpu\lib\multiprocessing\spawn.py", line 114, in _main
# ...
